# %%
from util import *
from datafed.CommandLib import API
import os
df_api = API()


file_name = "./test_data/HiGl_m750415.ibw"
collection_id = 'c/p_2022_afm_oxford_root'

# %%
json_output = get_metadata(file_name)

# %%
ls_resp = df_api.collectionItemsList('c/p_2022_afm_oxford_root', count=50)

# %%
print(ls_resp)
# Out:
# (offset: 0
# count: 50
# total: 0
# , 'ListingReply')

# %%
try: 
    del json_output['Flatten Offsets 0']
except:
    pass

try:
    del json_output['Flatten Slopes 0']
except:
    pass

try:
    del json_output['Flatten Slopes 4']
except:
    pass

try: 
    del json_output['Flatten Offsets 4']
except:
    pass

try: 
    del json_output['Flatten Offsets 1']
except:
    pass

try:
    del json_output['Flatten Slopes 1']
except:
    pass

for i, (key, value) in enumerate(json_output.items()):
      if value == np.NINF:
        json_output[key] = '-Inf'

for i, (key, value) in enumerate(json_output.items()):
      if value == np.Inf:
        json_output[key] = 'Inf'

# %%
file_name
# Out:
# './test_data/HiGl_m750415.ibw'

# %%
json_output
# Out:
# {'ScanSize': 1e-06,
#  'FastScanSize': 1e-06,
#  'SlowScanSize': 1e-06,
#  'ScanRate': 27902,
#  'XOffset': 0.00091221,
#  'YOffset': 0.027886,
#  'PointsLines': 1024,
#  'ScanPoints': 1024,
#  'ScanLines': 1024,
#  'ScanAngle': 0,
#  'ImagingMode': 'AC Mode',
#  'InvOLS': 0.0012477,
#  'SpringConstant': 17192,
#  'AmpInvOLS': 1.36e-05,
#  'Amp2Invols': 2e-08,
#  'FastRatio': 1,
#  'SlowRatio': 1,
#  'TopLine': 255,
#  'BottomLine': 0,
#  'ScanMode': 'Closed Loop',
#  'NapMode': 0,
#  'FMapScanTime': 17217,
#  'FMapScanPoints': 32,
#  'FMapScanLines': 32,
#  'FMapXYVelocity': 0.38824,
#  'FMapBookWise': 0,
#  'Channel1DataType': 'Height',
#  'DataTypeSum': 27,
#  'PhaseOffset': 325831947224942,
#  'PhaseOffset1': 0,
#  'NapPhaseOffset': 90,
#  'VoltageParm': 0,
#  'NapParms': 0,
#  'PreScanSetting': 0,
#  'OrcaOffset': 0,
#  'OrcaOffset2': 0,
#  'UserIn0Gain': 1,
#  'UserIn0Offset': 0,
#  'UserIn1Gain': 1,
#  'UserIn1Offset': 0,
#  'UserIn2Gain': 1,
#  'UserIn2Offset': 0,
#  'LateralGain': 1,
#  'LateralOffset': 0,
#  'OrcaGain': 'NaN',
#  'OrcaGain2': 'NaN',
#  'FastMapScanRate': 19531,
#  'FastMapZRate': 500,
#  'dcdvPhaseOffset': 0,
#  'dcdZPhaseOffset': 0,
#  'FastSkipLines': 4,
#  'FastReturnLines': 8,
#  'BackPackIn0Offset': 0,
#  'BackPackIn0Gain': 1,
#  'BackPackIn1Offset': 0,
#  'BackPackIn1Gain': 1,
#  'BackPackIn2Offset': 0,
#  'BackPackIn2Gain': 1,
#  'BackPackIn3Offset': 0,
#  'BackPackIn3Gain': 1,
#  'BackPackIn4Offset': 0,
#  'BackPackIn4Gain': 1,
#  'bDFilterCube': 1,
#  'Real Parms': 'End',
#  'Initial Parms': 'End',
#  'Initial ScanSize': 1e-06,
#  'Initial FastScanSize': 1e-06,
#  'Initial SlowScanSize': 1e-06,
#  'Initial ScanRate': 27902,
#  'ScanSpeed': 0.069754,
#  'Initial XOffset': 0.00091221,
#  'Initial YOffset': 0.027886,
#  'Initial ScanPoints': 1024,
#  'Initial ScanLines': 1024,
#  'RoundFactor': 4,
#  'IntegralGain': 85,
#  'ProportionalGain': 0,
#  'Initial ScanAngle': 0,
#  'ScanAngleFactor': 1,
#  'AmplitudeSetpointVolts': 27,
#  'AmplitudeSetpointMeters': 1e-08,
#  'DriveAmplitude': 79346,
#  'DriveFrequency': 1226171646267176,
#  'SweepWidth': 54834,
#  'SlowScanEnabled': 1,
#  'DeflectionSetpointVolts': 1,
#  'DeflectionSetpointMeters': 0,
#  'DeflectionSetpointNewtons': 5e-09,
#  'Initial ImagingMode': 1,
#  'MaxScanSize': 11,
#  'Initial InvOLS': 0.0012477,
#  'Initial SpringConstant': 17192,
#  'DisplaySpringConstant': 0.00017192,
#  'ScanStateChanged': 0,
#  'ScanDown': 0,
#  'XLVDTSens': 0.092981,
#  'YLVDTSens': 0.094755,
#  'ZLVDTSens': 0.0084601,
#  'XLVDTOffset': 38,
#  'YLVDTOffset': -4,
#  'ZLVDTOffset': 0,
#  'YIgain': 385,
#  'YPgain': '-Inf',
#  'XIgain': 375,
#  'XPgain': '-Inf',
#  'LastScan': 0,
#  'XPiezoSens': -0.0059126,
#  'YPiezoSens': 0.0060955,
#  'ZPiezoSens': 0.00052492,
#  'XDriveOffset': 0,
#  'YDriveOffset': 0,
#  'SweepPoints': 480,
#  'SecretGain': 0,
#  'YSgain': 64,
#  'XSgain': 64,
#  'DIsplayLVDTTraces': 0,
#  'Initial PhaseOffset': 32583,
#  'BaseSuffix': 415,
#  'SaveImage': 2,
#  'ParmChange': 0,
#  'ADCgain': 0,
#  'OldADCgain': 12,
#  'OldScanSize': 'NaN',
#  'OldYOffset': 0.027595,
#  'OldXOffset': 0.00084298,
#  'ZIgain': 4,
#  'ZPgain': '-Inf',
#  'ZSgain': 0,
#  'Initial AmpInvOLS': 1.36e-05,
#  'UpdateCounter': 106,
#  'DoMunge': 0,
#  'XMungeAlpha': 1,
#  'YMungeAlpha': 1,
#  'ZMungeAlpha': 1,
#  'StartScannerTemp': '127_94 °C',
#  'Has1xACDeflGain': 1,
#  'DontChangeXPT': 0,
#  'LowNoise': 1,
#  'ScreenRatio': 75,
#  'XDriftRate': 1.1312e-05,
#  'YDriftRate': 4.7588e-05,
#  'XDriftTotal': 0,
#  'YDriftTotal': 0,
#  'DriftBIts': 1,
#  'DriftCount': 15,
#  'Setpoint': 8,
#  'Initial FastRatio': 1,
#  'Initial SlowRatio': 1,
#  'Initial TopLine': 255,
#  'Initial BottomLine': 0,
#  'ScanStatus': 2,
#  'Is1DPlus': 0,
#  'DelayUpdate': 1,
#  'MarkerRatio': 0,
#  'StartLineCount': 0,
#  'OldAmplitudeSetpointVolts': 27,
#  'OldDeflectionSetPointVolts': 0,
#  'Initial ScanMode': 0,
#  'Interpolate': -1248,
#  'TipVoltage': 0,
#  'SurfaceVoltage': 0,
#  'FreqIgain': 5,
#  'FreqPgain': 0,
#  'FreqSgain': 0,
#  'Initial OrcaGain': 'NaN',
#  'FreqGainOn': 0,
#  'Initial UserIn0Gain': 1,
#  'Initial UserIn1Gain': 1,
#  'Initial UserIn2Gain': 1,
#  'Initial LateralGain': 1,
#  'IsBipolar': 0,
#  'FrequencyHack': 0,
#  'MagneticField': 'NaN',
#  'DriveGainOn': 0,
#  'DriveIGain': 50,
#  'DrivePGain': 0,
#  'DriveSGain': 0,
#  'Initial UserIn0Offset': 0,
#  'Initial UserIn1Offset': 0,
#  'Initial UserIn2Offset': 0,
#  'Initial LateralOffset': 0,
#  'LastImage': 0,
#  'ZoomSize': 0,
#  'ZoomXOffset': 0,
#  'ZoomYOffset': 0,
#  'User0Voltage': 0,
#  'User1Voltage': 0,
#  'ExtendedZ': 0,
#  'DriveAmplitude1': 6,
#  'DriveFrequency1': 450000,
#  'SweepWidth1': 5000,
#  'Initial PhaseOffset1': 0,
#  'Initial Amp2InvOLS': 2e-08,
#  'Initial VoltageParm': 0,
#  'MicroscopeID': 6,
#  'CapacitanceSens': 1,
#  'CapacitanceOffset': 0,
#  'CapPhaseOffset': 0,
#  'TipBiasOffset': 0,
#  'TipHeaterOffset': 0,
#  'SurfaceBiasOffset': 0,
#  'UseCantHolder': 0,
#  'CurrentCantHolder': 15,
#  'HasClickRing': 1,
#  'XScanDirection': -1,
#  'YScanDirection': 1,
#  'SaveImageCount': 3,
#  'SaveImageLines': 256,
#  'Initial OrcaGain2': 'NaN',
#  'UpdateSlowWave': 0,
#  'FBFilterBW': 5000,
#  'CurrentSetpointAmps': 1,
#  'CurrentSetpointVolts': 1,
#  'OldCurrentSetpointVolts': 1,
#  'OldCurrentSetpointAmps': 1,
#  'HasFM': 1,
#  'LastScanWithdraw': 0,
#  'HasLaserRelay': 1,
#  'ToggleLaserRelay': 0,
#  'Decimation': 7,
#  'DARTIGain': 55,
#  'DARTPGain': 0,
#  'SampleHolder': 1,
#  'ManualSampleHolder': 0,
#  'CypherXPTLock': 0,
#  'XPTLock': 0,
#  'LogFeedback': 0,
#  'ARSysScanBusy': 0,
#  'SimpleControls': 0,
#  'Initial PointsLines': 1024,
#  'FreeAirAmplitude': 40424,
#  'FreeAirPhase': 76103,
#  'FreeAirDeflection': 'NaN',
#  'FreeAirDriveAmplitude': 0,
#  'ContinualRetune': 0,
#  'ForceFilter': 0,
#  'TemperatureSens': 1,
#  'TemperatureOffset': 0,
#  'OffsetBehavior': 0,
#  'InputRange': 5,
#  'XLVDTSensSlope': 0,
#  'YLVDTSensSlope': 0,
#  'XLVDTSensIntercept': 0,
#  'YLVDTSensIntercept': 0,
#  'HaveWeKilledTheProgressBar': 1,
#  'Initial PreScanSetting': 0,
#  'ImageFrameTime': 367,
#  'FBFilterSelectivity': 0,
#  'HasDriveChoke': 1,
#  'DriveChokeOn': 0,
#  'CFCWFOS': 0,
#  'SkewAngle': 0,
#  'ContinualRetuneTime': 60,
#  'DRTimeStamp': 36478000000000,
#  'CRTimeStamp': 0,
#  'Cypher15VPower': 1,
#  'HasBlueDrive': 1,
#  'BlueDriveOn': 0,
#  'blueDriveOffset': 58142,
#  'blueDriveMaxAmplitude': 23181,
#  'bDDriveAmplitude': 21002,
#  'bDDriveAmplitude1': 2,
#  'bDDiffEfficiencyV': 7765,
#  'Initial BackPackIn0Gain': 1,
#  'Initial BackPackIn0Offset': 0,
#  'Initial BackPackIn1Gain': 1,
#  'Initial BackPackIn1Offset': 0,
#  'Initial BackPackIn2Gain': 1,
#  'Initial BackPackIn2Offset': 0,
#  'Initial BackPackIn3Gain': 1,
#  'Initial BackPackIn3Offset': 0,
#  'Initial BackPackIn4Gain': 1,
#  'Initial BackPackIn4Offset': 0,
#  'bdReCalibrateTime': 1,
#  'bdMotorError': 0,
#  'ScanModeGUI': 0,
#  'FastMapSetpointVolts': 1,
#  'FastMapSetpointNewtons': 0.002145,
#  'OldFastMapSetpointVolts': 1,
#  'OldFastMapSetpointNewtons': 1,
#  'Initial FastMapZRate': 500,
#  'FastMapAmplitude': 1.5e-07,
#  'FastMapFBMethod': 0,
#  'FastMapFBPhase': 0,
#  'FastMapFBWindow': 10,
#  'FastMapAmpSetpointVolts': 18,
#  'FastMapAmpSetpointMeters': 2.448e-05,
#  'FastMapIndex': 0,
#  'QueueProgress': 0,
#  'QueueEstimate': 0,
#  'QueueExpand': 0,
#  'FastMapIGain': 41276,
#  'Initial FastMapScanRate': 19531,
#  'FastMapBaseLine': 0,
#  'blueThermOn': 0,
#  'FMapFreqSetpointHertz': 100,
#  'FMapDispSetpointVolts': 5,
#  'OldFMapFreqSetpointHertz': 100,
#  'OldFMapDispSetpointVolts': 5,
#  'OldFastMapAmpSetpointVolts': 2.8078e-05,
#  'OldFastMapAmpSetpointMeters': 2.8078e-05,
#  'FastMapScanPoints': 256,
#  'FastMapScanLines': 256,
#  'FastMapOptScanPoints': 256,
#  'FastMapOptScanLines': 256,
#  'DisplaySpringConstant2': 1e-15,
#  'Springconstant2': 0,
#  'FreqDGain': 0,
#  'DriveDGain': 0,
#  'ImageSaveExpand': 0,
#  'Saturated': 100,
#  'FreeAirDissipation': 'NaN',
#  'IlluminatePercent': 90,
#  'ImageFormatMode': 0,
#  'ScanDirMode': 0,
#  'SinusoidalOn': 0,
#  'FrameCount': 0,
#  'ScanShape': 0,
#  'Initial FastReturnLines': 8,
#  'Initial FastSkipLines': 4,
#  'TimeShift': 0,
#  'FastInputFilter': 0,
#  'IMSScanStateChanged': 0,
#  'FastZPiezoSens': 0.00036124,
#  'UpdateFrameOnly': 0,
#  'FastScopeLine': 256,
#  'TimeShiftDisplay': 0,
#  'TimeShiftTotal': 0,
#  'ShouldSSCBeSet': 0,
#  'FastMapCaptureRate': 0,
#  'bDMaskGain': 1,
#  'BlueDriveMaxAmplitudeWatts': 18,
#  'FMapDispSetpointWatts': 144,
#  'OldFMapDispSetpointWatts': 5,
#  'FMFBFilterBW': 1500,
#  'IsLDV': 0,
#  'FastMapAmpRelativeSetpointVolts': 8,
#  'FastMapAmpRelativeSetpointMeter': 0.0001088,
#  'FastMapAbsoluteSetpointNewtons': 0.002145,
#  'FastMapAbsoluteSetpointVolts': 1,
#  'OldFastMapAmpRelativeSetpointVo': 8,
#  'OldFastMapAmpRelativeSetpointMe': 8.72e-06,
#  'OldFastMapAbsoluteSetpointNewto': 1e-07,
#  'OldFastMapAbsoluteSetpointVolts': 1,
#  'FFMapRelativeTrigger': 0,
#  'StageIsMoving': 0,
#  'FlipBiasSignWithdrawDist': 5e-09,
#  'ZMaxScanSize': 0.00012,
#  'bdMaskHomed': 1,
#  'FreeAirAmplitude2': 'NaN',
#  'FreeAirPhase2': 'NaN',
#  'LastThreadHandle': 3903,
#  'StartHeaterTemp': 'NaN °C',
#  'StartHeaterHumidity': 'NaN',
#  'MicroscopeModel': 'Jupiter',
#  'BlueDriveDissipationInWatts': 0,
#  'NapIntegralGain': 10,
#  'NapProportionalGain': 0,
#  'NapDeflectionSetpointVolts': 5,
#  'NapAmplitudeSetpointVolts': 8,
#  'NapDissipationSetpointVolts': 2,
#  'NapFrequencySetPointHz': 0,
#  'NapCurrentSetpointAmps': 1,
#  'NapDriveAmplitude': 8,
#  'NapDriveFrequency': 10336000000,
#  'NapDriveAmplitude1': 0,
#  'NapDriveFrequency1': 4200000,
#  'NapTipVoltage': 3,
#  'NapSurfaceVoltage': 0,
#  'NapUser0Voltage': 0,
#  'NapUser1Voltage': 0,
#  'NapHeight': 5e-08,
#  'NapStartHeight': 0,
#  'NapTime': 10016,
#  'PotentialIGain': 3,
#  'PotentialPGain': 0,
#  'PotentialGainOn': 0,
#  'ElectricTune': 0,
#  'NapCurrentSetpointVolts': 1,
#  'PotentialLoopLimit': 9,
#  'ClosedNap': 0,
#  'NapZIGain': 85,
#  'NapZPGain': 0,
#  'AutoNapZGain': 1,
#  'bDNapDriveAmplitude': 2,
#  'bDNapDriveAmplitude1': 2,
#  'Channel2DataType': 'Amplitude',
#  'Channel3DataType': 'Phase',
#  'Channel4DataType': 'ZSensor',
#  'Channel5DataType': 'None',
#  'Channel6DataType': 'None',
#  'Channel7DataType': 'None',
#  'Channel8DataType': 'None',
#  'UserCalcFunc': 'CalcPhaseFromIQ',
#  'UserCalcBFunc': 'CalcAmpFromIQ',
#  'FastMap1DataType': 'Height',
#  'FastMap2DataType': 'Amplitude',
#  'FastMap3DataType': 'Phase',
#  'FastMap4DataType': 'Off',
#  'FastMapCapture': 1,
#  'InA': 'Ground',
#  'InB': 'Ground',
#  'InFast': 'ACDefl',
#  'InAOffset': 'Ground',
#  'InBOffset': 'Ground',
#  'InFastOffset': 'Ground',
#  'OutXMod': 'Off',
#  'OutYMod': 'Off',
#  'OutZMod': 'Off',
#  'FilterIn': 'Ground',
#  'BNCOut0': 'Ground',
#  'BNCOut1': 'Ground',
#  'BNCOut2': 'Ground',
#  'PogoOut': 'Ground',
#  'Chip': 'Ground',
#  'Shake': 'DDS',
#  'Input_Z_Filter_Freq': 35714,
#  'Input_X_Filter_Freq': 35714,
#  'Input_Y_Filter_Freq': 35714,
#  'Input_A_Filter_Freq': 35714,
#  'Input_B_Filter_Freq': 35714,
#  'Input_Fast_Filter_Freq': 35714,
#  'Lockin_0_Filter_Freq': 35714,
#  'Lockin_1_Filter_Freq': 35714,
#  'Cypher_Input_FastA_Filter_Freq': 35714,
#  'Cypher_Input_FastB_Filter_Freq': 35714,
#  'Cypher_Input_A_Filter_Freq': 35714,
#  'Cypher_Input_B_Filter_Freq': 35714,
#  'Cypher_Input_C_Filter_Freq': 35714,
#  'Cypher_LVDT_X_Filter_Freq': 1000,
#  'Cypher_LVDT_Y_Filter_Freq': 1000,
#  'Cypher_LVDT_Z_Filter_Freq': 35714,
#  'Cypher_LockinA_0_Filter_Freq': 5000,
#  'Cypher_LockinA_1_Filter_Freq': 35714,
#  'Cypher_LockinB_0_Filter_Freq': 35714,
#  'Cypher_LockinB_1_Filter_Freq': 35714,
#  'Cypher_PIDSLoop_Fast_Input_': 0,
#  'Sample Rate': 71429,
#  'ThermalDC': 4.039e-13,
#  'ThermalQ': 76997,
#  'ThermalFrequency': 12262000000,
#  'ThermalWhiteNoise': 1.5337e-09,
#  'ScaleLog': 3,
#  'FitWidth': 20517,
#  'ThermalSamples': 1000,
#  'ThermalCounter': 315,
#  'SectionSamples': 10,
#  'SectionCounter': 0,
#  'DoThermal': 0,
#  'ThermalResolution': 4,
#  'ThermalZoom': 1,
#  'DoCantTune': 0,
#  'ZoomCounter': 200,
#  'AutoTuneLow': 900000,
#  'AutoTuneHigh': 11000000,
#  'TargetVoltage': 4,
#  'TargetPercent': 0,
#  'CheckTuneTraces': 0,
#  'ButtonTime': 245260000000000,
#  'ShowThermalFit': 1,
#  'AppendThermalBit': 8,
#  'TuneQ': 100,
#  'TuneGain': 0,
#  'TunePeakResult': 40415,
#  'TuneFreqResult': 12264000000,
#  'TuneQResult': 71525,
#  'ThermalSamplesLimit': 0,
#  'TuneFeedback': 0,
#  'TuneDDSOutput': 0,
#  'TipVoltCenter': 0,
#  'TipVoltWidth': 10,
#  'ThermalFrequencyRange': 3,
#  'AutoTuneLimit': 1,
#  'AutoTuneLow1': 5168000000,
#  'AutoTuneHigh1': 77519000000,
#  'TargetVoltage1': 1,
#  'TargetPercent1': 0,
#  'DualACMode': 0,
#  'WhichACMode': 0,
#  'BackwardsTune': 0,
#  'TuneCaptureRate': 500,
#  'TuneTime': 96,
#  'TuneFilter': 500,
#  'iDriveOn': 0,
#  'FrequencyRatio': 367,
#  'DFRTFrequencyCenter': 8380900000,
#  'DFRTFrequencyWidth': 7761700000,
#  'DFRTOn': 0,
#  'ThermalCenter': 1224000000,
#  'ThermalWidth': 122400000,
#  'DFWMAMT': 0,
#  'LastXPos': 71076,
#  'LastYPos': 71248,
#  'PFMFrequencyLimit': 'Inf',
#  'TuneLockin': 1,
#  'TipHeaterDrive': 0,
#  'AdjustSpringConstant': 0,
#  'DrawThermalFit': 0,
#  'LateralTune': 0,
#  'ThermalTemperature': 30124,
#  'UseCypherThermal': 1,
#  'UseCypherMultiThread': 0,
#  'Illumination': 86649,
#  'ARCZ': 0,
#  'TuneAngle': -90,
#  'IsDefaultFrequency': 1,
#  'TargetAmplitude': 0,
#  'TargetPhase': 90,
#  'LossTanAmp1': 39945,
#  'LossTanPhase1': 71413,
#  'LossTanAmp2': 0.61989,
#  'LossTanPhase2': -15999,
#  'LossTanFreq1': 12262000000,
#  'LossTanFreq2': 0,
#  'LossTanQ1': 71525,
#  'LossTanQ2': 0,
#  'SecondFrequency': 0,
#  'TryFitAgain': 0,
#  'HighFrequencyMode': 0,
#  'ThermalLever': 'Custom',
#  'DoSader': 0,
#  'CustomLeverLength': 3e-05,
#  'CustomLeverWidth': 2e-05,
#  'CustomLeverFrequency': 1000000,
#  'ResFreq1': 1226171650948389,
#  'ResFreq2': 0,
#  'GetStartedRoughness': 3,
#  'GetStartedOn': 0,
#  'GSGainGain': 1,
#  'GSSetpointPercent': 50,
#  'GSHardness': 0,
#  'GSLeverRange': 1,
#  'GetStartedMorePanel': 0,
#  'GSUseManualThermal': 0,
#  'GSMotorHeight': 0,
#  'GSStickySample': 0,
#  'GSDateTime': 1,
#  'ThermalToolsOn': 0,
#  'ThermalGraphNoControls': 0,
#  'ThermalGraphStatus': 3,
#  'ThermalCenterHigh': 4500000,
#  'ThermalWidthHigh': 100000,
#  'FitWidthHigh': 80000,
#  'ThermalFrequencyHigh': 4500000,
#  'ThermalQHigh': 20,
#  'ThermalDCHigh': 1e-14,
#  'ThermalWhiteNoiseHigh': 5e-15,
#  'TuneGraphNoControls': 0,
#  'TuneGraphMode': 0,
#  'TuneToolsOn': 0,
#  'TuneDrive': 0,
#  'TuneQResult1': 15891,
#  'K2Exponent': 2,
#  'BadThermal': 0,
#  'YourVariablesStartHere': 0,
#  'Log File': 'Stop',
#  'Date': '2019-08-04',
#  'Seconds': 36477791916,
#  'Inside Temp': '28_057 °C',
#  'UserCalcUnit': '°',
#  'UserIn0Unit': 'V',
#  'UserIn1Unit': 'V',
#  'UserIn2Unit': 'V',
#  'LateralUnit': 'V',
#  'ARUserPanelName': '',
#  'UserIn0Name': '',
#  'UserIn1Name': '',
#  'UserIn2Name': '',
#  'UserCalcName': '',
#  'UserIn0Ab': '',
#  'UserIn1Ab': '',
#  'UserIn2Ab': '',
#  'UserCalcAb': '',
#  'UserIn0Force': '',
#  'UserIn1Force': '',
#  'UserIn2Force': '',
#  'UserCalcForce': '',
#  'NavLoadPath': '',
#  'LastNavLoadPath': '',
#  'UserCalcBUnit': '',
#  'UserCalcBName': '',
#  'UserCalcBForce': '',
#  'UserCalcBAb': '',
#  'BackPackIn0Unit': 'V',
#  'BackPackIn0Name': '',
#  'BackPackIn0Ab': '',
#  'BackPackIn0Force': '',
#  'BackPackIn1Unit': 'V',
#  'BackPackIn1Name': '',
#  'BackPackIn1Ab': '',
#  'BackPackIn1Force': '',
#  'BackPackIn2Unit': 'V',
#  'BackPackIn2Name': '',
#  'BackPackIn2Ab': '',
#  'BackPackIn2Force': '',
#  'BackPackIn3Unit': 'V',
#  'BackPackIn3Name': '',
#  'BackPackIn3Ab': '',
#  'BackPackIn3Force': '',
#  'BackPackIn4Unit': 'V',
#  'BackPackIn4Name': '',
#  'BackPackIn4Ab': '',
#  'BackPackIn4Force': '',
#  'DetectorSum': 'Input_x',
#  'XSensor': 'Cypher_LVDT_X',
#  'YSensor': 'Cypher_LVDT_Y',
#  'ZSensor': 'Cypher_LVDT_Z',
#  'DDSAmplitude0': '$Lockin_0_Amp',
#  'DDSDCOffset0': '$Lockin_DCOffset',
#  'DDSFrequency0': '$Lockin_0_Freq',
#  'DDSFrequencyOffset0': '$Lockin_0_FreqOffset',
#  'DDSPhaseOffset0': '$Lockin_0_PhaseOffset',
#  'DDSAmplitude1': '$Lockin_1_Amp',
#  'DDSFrequency1': '$Lockin_1_Freq',
#  'DDSPhaseOffset1': '$Lockin_1_PhaseOffset',
#  'Amplitude': '$Lockin_0_r',
#  'Phase': '$Lockin_0_theta',
#  'Inputi': '$Lockin_0_i',
#  'Inputq': '$Lockin_0_q',
#  'Inputi1': '$Lockin_1_i',
#  'Inputq1': '$Lockin_1_q',
#  'Count': 'Input_Counter0',
#  'Count2': 'Input_Counter1',
#  'Potential': '$DDSDCOffset0',
#  'Amplitude1': '$Lockin_1_r',
#  'Phase1': '$Lockin_1_theta',
#  'DDSQGain0': '$Lockin_0_QGain',
#  'DDSQAngle0': '$Lockin_0_QAngle',
#  'DDSFrequencyOffset1': '$Lockin_1_FreqOffset',
#  'Deflection': 'Cypher_Input_FastB',
#  'Lateral': 'Input_Y',
#  'Frequency': '$DDSFrequencyOffset0',
#  'LockIn': 'Cypher_LockinA',
#  'Height': 'Cypher_Output_Z',
#  'Dissipation': '$DDSAmplitude0',
#  'DeflectionValue': 'Polycombo_0_Output',
#  'FastMapFBInput': 'Cypher_FFMod_AbsPeak',
#  'Drive': 'Cypher_PolyCombo_1_Output',
#  'HeightLoop': 'Cypher_PIDSloop_2',
#  'VerDate': 170064,
#  'Version': 170064,
#  'XopVersion': 1708921137,
#  'OSVersion': 'Windows version 10_0 Professional  (Build 17763)',
#  'IgorFileVersion': 6381,
#  'BaseName': 'HiGl_m75',
#  'SkewAngleRead': '89_99999 °',
#  'ImageNote': 'multi75gd-g piezo',
#  'TipSerialNumber': '',
#  'Planefit 0': 'Flatten 1',
#  'PlanefitOrder 0': -1,
#  'FlattenOrder 0': 1,
#  'Planefit Offset 0': -0.0079702,
#  'Planefit X Slope 0': 0,
#  'Planefit Y Slope 0': 0,
#  'Display Offset 0': 0,
#  'Display Range 0': 2.6e-08,
#  'ColorMap 0': 'Mud',
#  'Planefit 1': 'Flatten 1',
#  'PlanefitOrder 1': -1,
#  'FlattenOrder 1': 1,
#  'Planefit Offset 1': -0.0079668,
#  'Planefit X Slope 1': 0,
#  'Planefit Y Slope 1': 0,
#  'Display Offset 1': 0,
#  'Display Range 1': 2.6e-08,
#  'ColorMap 1': 'Mud',
#  'Planefit 2': 'None',
#  'PlanefitOrder 2': -1,
#  'FlattenOrder 2': -1,
#  'Planefit Offset 2': 3.6517e-05,
#  'Planefit X Slope 2': 0,
#  'Planefit Y Slope 2': 0,
#  'Display Offset 2': 3.6517e-05,
#  'Display Range 2': 5.8e-09,
#  'ColorMap 2': 'Grays256',
#  'Planefit 3': 'None',
#  'PlanefitOrder 3': -1,
#  'FlattenOrder 3': -1,
#  'Planefit Offset 3': 5243,
#  'Planefit X Slope 3': 0,
#  'Planefit Y Slope 3': 0,
#  'Display Offset 3': 5243,
#  'Display Range 3': 175,
#  'ColorMap 3': 'Grays256',
#  'Planefit 4': 'Flatten 1',
#  'PlanefitOrder 4': -1,
#  'FlattenOrder 4': 1,
#  'Planefit Offset 4': -0.0009939,
#  'Planefit X Slope 4': 0,
#  'Planefit Y Slope 4': 0,
#  'Display Offset 4': 0,
#  'Display Range 4': 9.3e-09,
#  'ColorMap 4': 'Grays256',
#  'EndScannerTemp': '85 °C',
#  'ARDataType': 'AFMImage',
#  'FileName': 'HiGl_m750415_ibw',
#  'creationDate': 3373459566,
#  'modDate': 3648479993,
#  'bname': "b'HiGl_m750415'"}

# %%
def _send_ibw_to_datafed(file_name, collection_id):
    df_api = API()
    
    json_output = get_metadata(file_name)

    # This removes flattening information and fixes inf values in metadata
    try: 
        del json_output['Flatten Offsets 0']
    except:
        pass

    try:
        del json_output['Flatten Slopes 0']
    except:
        pass

    try:
        del json_output['Flatten Slopes 4']
    except:
        pass

    try: 
        del json_output['Flatten Offsets 4']
    except:
        pass

    try: 
        del json_output['Flatten Offsets 1']
    except:
        pass

    try:
        del json_output['Flatten Slopes 1']
    except:
        pass

    for i, (key, value) in enumerate(json_output.items()):
        if value == np.NINF:
            json_output[key] = '-Inf'

    for i, (key, value) in enumerate(json_output.items()):
        if value == np.Inf:
            json_output[key] = 'Inf'

    try:
        # creates a new data record
        dc_resp = df_api.dataCreate(os.path.basename(file_name), # file name
                                # metadata=json.dumps(json_output), # metadata
                                parent_id=collection_id, # parent collection
                            )
    except Exception:
        print(file_name)
        print(json_output)
        print(collection_id)
        print('There was an error creating the DataRecord')

    try: 
        # extracts the record ID
        rec_id = dc_resp[0].data[0].id
    except ValueError:
        print('Could not find record ID')

    try:
        # sends the put command
        put_resp = df_api.dataPut(rec_id,
                                    file_name,
                                    wait = False)
    except Exception:
        print('Could not intiate globus transfer')

# %%
os.path.is

# %%
import glob
import os

file_name = r'C:\Users\Joshua Agar\OneDrive - Drexel University\Documents\Data_Analysis\AFM_to_DataFed\test_data'

if os.path.isdir(file_name):
    file_list = glob.glob(file_name + "\**\*.ibw", recursive= True)

# %%
file_list
# Out:
# ['C:\\Users\\Joshua Agar\\OneDrive - Drexel University\\Documents\\Data_Analysis\\AFM_to_DataFed\\test_data\\HiGl_m750506.ibw',
#  'C:\\Users\\Joshua Agar\\OneDrive - Drexel University\\Documents\\Data_Analysis\\AFM_to_DataFed\\test_data\\HiGl_m750558.ibw',
#  'C:\\Users\\Joshua Agar\\OneDrive - Drexel University\\Documents\\Data_Analysis\\AFM_to_DataFed\\test_data\\1\\HiGl_m750517.ibw',
#  'C:\\Users\\Joshua Agar\\OneDrive - Drexel University\\Documents\\Data_Analysis\\AFM_to_DataFed\\test_data\\2\\sub2\\HiGl_m750415.ibw']

# %%
dc_resp = df_api.dataCreate(os.path.basename(file_name), # file name
                            metadata=json.dumps(json_output), # metadata
                            parent_id=collection_id, # parent collection
                           )

# %%
dc_resp = df_api.dataCreate(os.path.basename(file_name), # file name
                            metadata=json.dumps(json_output), # metadata
                            parent_id=collection_id, # parent collection
                           )

rec_id = dc_resp[0].data[0].id

put_resp = df_api.dataPut(rec_id,
                            file_name,
                            wait = False)

# %%
# for i, (key, value) in enumerate(json_output.items()):
#    #   if value == -inf:
#         print(key, value)

# %%
for idx, (obj, value) in enumerate(json_output.items()):
        if obj == 'Flatten Offsets 0':
            json_output.pop(idx)
